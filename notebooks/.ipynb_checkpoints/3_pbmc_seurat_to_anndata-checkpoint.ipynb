# %%
import numpy as np
import pandas as pd
import scanpy as sc
import anndata
from scipy import io
from scipy.sparse import coo_matrix, csr_matrix
import os
pd.set_option('display.max_columns', None)

# %%
os.chdir('/media/MPEdge16/MM137/sc/py/py_out/')

# %%
X = io.mmread("/media/MPEdge16/MM137/sc/seurat/pbmc/RNA_assay_counts.mtx")

# %%
adata = anndata.AnnData(X = X.transpose().tocsr())

# %%
metadata = pd.read_csv("/media/MPEdge16/MM137/sc/seurat/pbmc/seurat_meta.csv")

# %%
with open("/media/MPEdge16/MM137/sc/seurat/pbmc/gene_names.csv", "r") as f:
    gene_names = f.read().splitlines()

# %%
adata.obs = metadata
adata.obs.index = adata.obs['barcode_2']
adata.obs
# Out:
#                        orig.ident  nCount_RNA  nFeature_RNA  percent_mito  \
# barcode_2
# AAACCTGAGACCTAGG-1  SeuratProject        2581          1005      0.387447
# AAACCTGAGAGCCCAA-1  SeuratProject        1646           725      3.584447
# AAACCTGAGAGGTTGC-1  SeuratProject        4311          1966      3.757829
# AAACCTGAGAGTCGGT-1  SeuratProject        1764           959      2.040816
# AAACCTGAGATATGGT-1  SeuratProject        3794          1828      2.424881
# ...                           ...         ...           ...           ...
# TTTGTCATCGCATGGC-8  SeuratProject        4268          1818      2.085286
# TTTGTCATCGGTCCGA-8  SeuratProject        2495          1065      0.721443
# TTTGTCATCTGATACG-8  SeuratProject        2782          1367      1.042416
# TTTGTCATCTGGCGAC-8  SeuratProject        3172          1128      1.134931
# TTTGTCATCTGTCTCG-8  SeuratProject        2766          1147      0.903832
#
#                              barcode_1  lane              solo_X  \
# ...

# %%
adata.var.index = gene_names

# %%
adata.write("mm_pbmc.h5ad")
